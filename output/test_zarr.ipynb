# %%
from ecml_tools.data import open_dataset
ds = open_dataset("test_summer.zarr")

# %%
ds.dates
# Out:
# array(['2008-01-01T00:00:00.000000000', '2008-01-01T06:00:00.000000000',
#        '2008-01-01T12:00:00.000000000', '2008-01-01T18:00:00.000000000',
#        '2008-01-02T00:00:00.000000000', '2008-01-02T06:00:00.000000000',
#        '2008-01-02T12:00:00.000000000', '2008-01-02T18:00:00.000000000',
#        '2008-01-03T00:00:00.000000000', '2008-01-03T06:00:00.000000000',
#        '2008-01-03T12:00:00.000000000', '2008-01-03T18:00:00.000000000',
#        '2008-01-04T00:00:00.000000000', '2008-01-04T06:00:00.000000000',
#        '2008-01-04T12:00:00.000000000', '2008-01-04T18:00:00.000000000',
#        '2008-01-05T00:00:00.000000000', '2008-01-05T06:00:00.000000000',
#        '2008-01-05T12:00:00.000000000', '2008-01-05T18:00:00.000000000',
#        '2008-01-06T00:00:00.000000000', '2008-01-06T06:00:00.000000000',
#        '2008-01-06T12:00:00.000000000', '2008-01-06T18:00:00.000000000',
#        '2008-01-07T00:00:00.000000000', '2008-01-07T06:00:00.000000000',
#        '2008-01-07T12:00:00.000000000', '2008-01-07T18:00:00.000000000',
#        '2008-01-08T00:00:00.000000000', '2008-01-08T06:00:00.000000000',
#        '2008-01-08T12:00:00.000000000', '2008-01-08T18:00:00.000000000',
#        '2008-01-09T00:00:00.000000000', '2008-01-09T06:00:00.000000000',
#        '2008-01-09T12:00:00.000000000', '2008-01-09T18:00:00.000000000',
#        '2008-01-10T00:00:00.000000000', '2008-01-10T06:00:00.000000000',
#        '2008-01-10T12:00:00.000000000', '2008-01-10T18:00:00.000000000',
#        '2008-01-11T00:00:00.000000000', '2008-01-11T06:00:00.000000000',
#        '2008-01-11T12:00:00.000000000', '2008-01-11T18:00:00.000000000',
#        '2008-01-12T00:00:00.000000000', '2008-01-12T06:00:00.000000000',
#        '2008-01-12T12:00:00.000000000', '2008-01-12T18:00:00.000000000',
#        '2008-01-13T00:00:00.000000000', '2008-01-13T06:00:00.000000000',
#        '2008-01-13T12:00:00.000000000', '2008-01-13T18:00:00.000000000',
#        '2008-01-14T00:00:00.000000000', '2008-01-14T06:00:00.000000000',
#        '2008-01-14T12:00:00.000000000', '2008-01-14T18:00:00.000000000',
#        '2008-01-15T00:00:00.000000000', '2008-01-15T06:00:00.000000000',
#        '2008-01-15T12:00:00.000000000', '2008-01-15T18:00:00.000000000',
#        '2008-01-16T00:00:00.000000000', '2008-01-16T06:00:00.000000000',
#        '2008-01-16T12:00:00.000000000', '2008-01-16T18:00:00.000000000',
#        '2008-01-17T00:00:00.000000000', '2008-01-17T06:00:00.000000000',
#        '2008-01-17T12:00:00.000000000', '2008-01-17T18:00:00.000000000',
#        '2008-01-18T00:00:00.000000000', '2008-01-18T06:00:00.000000000',
#        '2008-01-18T12:00:00.000000000', '2008-01-18T18:00:00.000000000',
#        '2008-01-19T00:00:00.000000000', '2008-01-19T06:00:00.000000000',
#        '2008-01-19T12:00:00.000000000', '2008-01-19T18:00:00.000000000',
#        '2008-01-20T00:00:00.000000000', '2008-01-20T06:00:00.000000000',
#        '2008-01-20T12:00:00.000000000', '2008-01-20T18:00:00.000000000',
#        '2008-01-21T00:00:00.000000000', '2008-01-21T06:00:00.000000000',
#        '2008-01-21T12:00:00.000000000', '2008-01-21T18:00:00.000000000',
#        '2008-01-22T00:00:00.000000000', '2008-01-22T06:00:00.000000000',
#        '2008-01-22T12:00:00.000000000', '2008-01-22T18:00:00.000000000',
#        '2008-01-23T00:00:00.000000000', '2008-01-23T06:00:00.000000000',
#        '2008-01-23T12:00:00.000000000', '2008-01-23T18:00:00.000000000',
#        '2008-01-24T00:00:00.000000000', '2008-01-24T06:00:00.000000000',
#        '2008-01-24T12:00:00.000000000', '2008-01-24T18:00:00.000000000',
#        '2008-01-25T00:00:00.000000000', '2008-01-25T06:00:00.000000000',
#        '2008-01-25T12:00:00.000000000', '2008-01-25T18:00:00.000000000',
#        '2008-01-26T00:00:00.000000000', '2008-01-26T06:00:00.000000000',
#        '2008-01-26T12:00:00.000000000', '2008-01-26T18:00:00.000000000',
#        '2008-01-27T00:00:00.000000000', '2008-01-27T06:00:00.000000000',
#        '2008-01-27T12:00:00.000000000', '2008-01-27T18:00:00.000000000'],
#       dtype='datetime64[ns]')

# %%
ds.statistics["mean"]
# Out:
# array([ 2.73716253e-06,  2.65997725e-06,  2.69505439e-06,  5.80897568e-06,
#         1.54529984e-05,  3.84881151e-05,  1.79787365e-04,  4.84557983e-04,
#         9.12160997e-04,  1.49929923e-03,  2.83093862e-03,  3.52370419e-03,
#         2.09265195e-03,  2.00633066e+05,  1.57606926e+05,  1.31802430e+05,
#         1.13558899e+05,  9.94128543e+04,  8.78165271e+04,  6.89158509e+04,
#         5.34561511e+04,  4.02836591e+04,  2.87778982e+04,  1.36061556e+04,
#         6.79309696e+03,  7.40757833e+02,  9.91602467e+04,  1.01370529e+05,
#         1.25394289e+02,  2.11440552e+02,  2.15521980e+02,  2.20102923e+02,
#         2.20810592e+02,  2.19385190e+02,  2.22755907e+02,  2.35366756e+02,
#         2.46770212e+02,  2.55844551e+02,  2.62946098e+02,  2.65541704e+02,
#         2.57111138e+02,  1.38746328e+02,  2.76831927e+02,  1.30810328e+01,
#         1.48087683e+01,  1.63198756e+01,  1.63597994e+01,  1.67598701e+01,
#         1.57548203e+01,  1.19848973e+01,  8.94865541e+00,  6.65242874e+00,
#         4.68673292e+00,  1.75855269e+00, -8.52887073e-02, -1.67427151e+00,
#        -1.38088922e+00,  1.14204955e+00, -8.55674281e-01, -2.06090660e+00,
#        -2.14688106e+00, -2.02293721e+00, -9.10714674e-01,  1.13785636e+00,
#         2.52066817e+00,  3.61420686e+00,  4.54785580e+00,  5.50169372e+00,
#         5.52924920e+00,  2.29089429e+00,  6.32015218e-04,  1.52596886e-03,
#         4.82747197e-04, -3.97374084e-03, -1.27319761e-02, -2.06162172e-02,
#        -2.58875726e-02, -2.62931604e-02, -2.62590189e-02, -2.59321618e-02,
#        -1.81809558e-02, -7.17061813e-03,  2.28431572e-03,  3.18127479e+00,
#         2.77538880e+02,  2.76831927e+02,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00,  6.17710132e-01,  9.85661853e-01,  7.81404650e-01,
#         8.44531521e-02, -3.52039309e-02,  9.85924294e-01, -1.33027286e-02,
#         8.10426954e-02,  0.00000000e+00,  0.00000000e+00,  1.84942020e+02,
#         4.32977109e-01])

# %%
import xarray as xr
import numpy as np
from plots import ZarrSinglePlotNoBoundaries
import matplotlib.pyplot as plt
from ecml_tools.data import open_dataset
from omegaconf import OmegaConf
ds = open_dataset("/home/mlx/ai-ml/datasets/metno-meps-archive-det-opendap-2p5km-2020-2023-6h-v1.zarr")
var = "q_50"
time = 0

fig, ax = plt.subplots(1,1, figsize=(12,8))
ZarrSinglePlotNoBoundaries(fig, ax, ds, var, time)
# plt.savefig(f'{var}_{ds.dates[time]}.png')
# Out:
# /perm/nld1247/conda/envs/aifs/lib/python3.10/site-packages/torch/cuda/__init__.py:619: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 7
#       5 from ecml_tools.data import open_dataset
#       6 from omegaconf import OmegaConf
# ----> 7 from aifs.data.datamodule import ECMLDataModule
#       8 ds = open_dataset("/home/mlx/ai-ml/datasets/metno-meps-archive-det-opendap-2p5km-2020-2023-6h-v1.zarr")
#       9 var = "q_50"
#
# ImportError: cannot import name 'ECMLDataModule' from 'aifs.data.datamodule' (/lus/h2resw01/hpcperm/nld1247/aifs-lam-dowa/aifs/data/datamodule.py)

# %%
plt.savefig(f'{var}_{ds.dates[time]}.png')

# %%
# check: statistics u and v, check if orography is imported and check land-sea-mask not zero
import xarray as xr
import numpy as np
from plots import ZarrSinglePlotNoBoundaries
import matplotlib.pyplot as plt
from ecml_tools.data import open_dataset
from omegaconf import OmegaConf
ds = open_dataset("test_summer.zarr")
var = "2d"
time = 7

fig, ax = plt.subplots(1,1, figsize=(12,8))
ZarrSinglePlotNoBoundaries(fig, ax, ds, var, time)
plt.savefig(f'{var}_{ds.dates[time]}.png')

# %%
seen = set()
uniq = [i for i, x in enumerate(ds.dates) if x not in seen and not seen.add(x)]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
scatter_plot(fig, ax, lon = ds.longitudes, lat = ds.latitudes, data = ds.data[0,53], cmap ="viridis")

# %%
import numpy as np
np.min(ds.data[0, 82])
# Out:
# -10.899485

# %%
ds.data[0, 82, :, 0:100]
# Out:
# array([[-1.242662  , -0.80828446, -0.4655429 , -0.3735061 , -0.4378161 ,
#         -0.29527897,  0.30541435,  0.7438423 ,  0.60747886,  0.29348484,
#          0.14010276,  0.08494735,  0.07867698, -0.08490847, -0.28013235,
#         -0.18840642, -0.07549804, -0.09345704, -0.16986088,  0.20930223,
#          0.19944833, -0.25540745, -0.68339384, -0.0729465 , -0.38709176,
#          0.79286647,  0.88733774, -0.28677586, -0.8986169 , -0.7019239 ,
#         -1.2305208 ,  0.59381443,  2.0058262 , -0.27996567, -0.04811834,
#          0.77118844,  1.1984693 ,  1.8251988 ,  0.77426434, -0.59342486,
#         -0.11095008,  0.01339691,  0.57744247,  0.9693594 ,  1.3283348 ,
#          1.9175317 ,  0.76289344,  0.727325  ,  1.4598831 ,  1.7786793 ,
#          1.0694647 ,  1.3517799 ,  1.1855993 ,  0.7826908 ,  1.4138407 ,
#          1.2838212 ,  0.66750455,  0.40146607,  0.6241691 ,  0.44330654,
#          0.95017064,  3.141731  ,  2.128923  ,  2.9179344 ,  3.1561499 ,
#          3.2409053 ,  2.31402   ,  1.2400376 ,  1.3160747 ,  0.9009174 ,
#         -0.80157673, -2.8235583 , -1.6661873 ,  1.6186897 ,  1.6080011 ,
#          0.3468761 ,  1.3605851 ,  2.0181053 ,  1.4286766 , -0.44870746,
#         -2.2584593 , -1.418451  ,  1.4753202 ,  1.4627776 ,  0.767183  ,
#          1.1716392 ,  0.87568545,  0.73140806, -0.6079289 , -0.22071382,
#          1.2955285 ,  1.7465947 ,  2.6189764 ,  2.0631993 ,  1.1063738 ,
#         -2.1491034 , -1.2101057 ,  0.20543589,  1.2890049 , -0.26653337]],
#       dtype=float32)

# %%
from scipy.ndimage import uniform_filter
np.min(uniform_filter(ds.data[0,39].reshape(789, 789), axes=[0, 1], size=32))
# Out:
# 49.026077

# %%
era = open_dataset("s3://ml-datasets/aifs-ea-an-oper-0001-mars-o96-1979-2022-6h-v5.zarr")

# %%
era[20000,23,0,:]
# Out:
# array([265.53967, 265.52014, 265.4342 , ..., 235.10216, 235.81114,
#        236.94981], dtype=float32)

# %%
ds.name_to_index["u_850"]
# Out:
# 53

# %%
ds.data.shape
# Out:
# (1180, 101, 1, 622521)

# %%
import numpy as np
np.sum(ds.data[0][28, 0], axis= 0)
# Out:
# nan

# %%
import pandas as pd
pd.Timedelta((ds.dates[1] - ds.dates[0]).astype("timedelta64")).total_seconds()
# Out:
# 10800.0

# %%
import numpy as np
np.char.index(ds.dates=='2008-08-09T00:00:00.000000000')
# Out:
# /tmp/ipykernel_420650/1189998827.py:2: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   np.where(ds.dates=='2008-08-09T00:00:00.000000000')
# (array([], dtype=int64),)

# %%
import numpy as np
nc_date = "20080115"
date = np.datetime64(nc_date[:4] + "-" + nc_date[4:6] + "-" + nc_date[6:8])
print(date == ds.dates[0])
# Out:
# True

# %%
print(ds.dates[0])
# Out:
# 2008-01-15T00:00:00.000000000

# %%
ds = open

# %%
set(['q_50', 'q_100', 'q_150', 'q_200', 'q_250', 'q_300', 'q_400', 'q_500', 'q_600', 'q_700', 'q_850', 'q_925', 'q_1000', 'z_50', 'z_100', 'z_150', 'z_200', 'z_250', 'z_300', 'z_400', 'z_500', 'z_600', 'z_700', 'z_850', 'z_925', 'z_1000', 'sp', 'msl', 't_50', 't_100', 't_150', 't_200', 't_250', 't_300', 't_400', 't_500', 't_600', 't_700', 't_850', 't_925', 't_1000', '2t', 'u_50', 'u_100', 'u_150', 'u_200', 'u_250', 'u_300', 'u_400', 'u_500', 'u_600', 'u_700', 'u_850', 'u_925', 'u_1000', '10u', 'v_50', 'v_100', 'v_150', 'v_200', 'v_250', 'v_300', 'v_400', 'v_500', 'v_600', 'v_700', 'v_850', 'v_925', 'v_1000', '10v', 'w_50', 'w_100', 'w_150', 'w_200', 'w_250', 'w_300', 'w_400', 'w_500', 'w_600', 'w_700', 'w_850', 'w_925', 'w_1000', '2d', 'sdor', 'slor', 'cp', 'tp', 'z', 'cos_latitude', 'cos_longitude', 'sin_latitude', 'sin_longitude', 'cos_julian_day', 'cos_local_time', 'sin_julian_day', 'sin_local_time', 'insolation', 'tcw', 'skt', 'lsm']) - set(ds.metadata_specific()["variables"])
# Out:
# {'z'}
